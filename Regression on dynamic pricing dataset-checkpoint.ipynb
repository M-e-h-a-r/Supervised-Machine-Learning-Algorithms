# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("dynamic_pricing.csv")

# %%
df
# Out:
#      Number_of_Riders  Number_of_Drivers Location_Category  \
# 0                  90                 45             Urban
# 1                  58                 39          Suburban
# 2                  42                 31             Rural
# 3                  89                 28             Rural
# 4                  78                 22             Rural
# ..                ...                ...               ...
# 995                33                 23             Urban
# 996                84                 29             Urban
# 997                44                  6          Suburban
# 998                53                 27          Suburban
# 999                78                 63             Rural
#
#     Customer_Loyalty_Status  Number_of_Past_Rides  Average_Ratings  \
# 0                    Silver                    13             4.47
# 1                    Silver                    72             4.06
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Number_of_Riders         1000 non-null   int64
#  1   Number_of_Drivers        1000 non-null   int64
#  2   Location_Category        1000 non-null   object
#  3   Customer_Loyalty_Status  1000 non-null   object
#  4   Number_of_Past_Rides     1000 non-null   int64
#  5   Average_Ratings          1000 non-null   float64
#  6   Time_of_Booking          1000 non-null   object
#  7   Vehicle_Type             1000 non-null   object
#  8   Expected_Ride_Duration   1000 non-null   int64
#  9   Historical_Cost_of_Ride  1000 non-null   float64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 78.3+ KB

# %%
df.isnull().sum()
# Out:
# Number_of_Riders           0
# Number_of_Drivers          0
# Location_Category          0
# Customer_Loyalty_Status    0
# Number_of_Past_Rides       0
# Average_Ratings            0
# Time_of_Booking            0
# Vehicle_Type               0
# Expected_Ride_Duration     0
# Historical_Cost_of_Ride    0
# dtype: int64

# %%
df.head()
# Out:
#    Number_of_Riders  Number_of_Drivers Location_Category  \
# 0                90                 45             Urban
# 1                58                 39          Suburban
# 2                42                 31             Rural
# 3                89                 28             Rural
# 4                78                 22             Rural
#
#   Customer_Loyalty_Status  Number_of_Past_Rides  Average_Ratings  \
# 0                  Silver                    13             4.47
# 1                  Silver                    72             4.06
# 2                  Silver                     0             3.99
# 3                 Regular                    67             4.31
# 4                 Regular                    74             3.77
#
#   Time_of_Booking Vehicle_Type  Expected_Ride_Duration  \
# 0           Night      Premium                      90
# 1         Evening      Economy                      43
# 2       Afternoon      Premium                      76
# ...

# %%
df.tail()
# Out:
#      Number_of_Riders  Number_of_Drivers Location_Category  \
# 995                33                 23             Urban
# 996                84                 29             Urban
# 997                44                  6          Suburban
# 998                53                 27          Suburban
# 999                78                 63             Rural
#
#     Customer_Loyalty_Status  Number_of_Past_Rides  Average_Ratings  \
# 995                    Gold                    24             4.21
# 996                 Regular                    92             4.55
# 997                    Gold                    80             4.13
# 998                 Regular                    78             3.63
# 999                    Gold                    14             4.21
#
#     Time_of_Booking Vehicle_Type  Expected_Ride_Duration  \
# 995         Morning      Premium                      11
# 996         Morning      Premium                      94
# ...

# %%
df.nunique()
# Out:
# Number_of_Riders             81
# Number_of_Drivers            79
# Location_Category             3
# Customer_Loyalty_Status       3
# Number_of_Past_Rides        101
# Average_Ratings             151
# Time_of_Booking               4
# Vehicle_Type                  2
# Expected_Ride_Duration      171
# Historical_Cost_of_Ride    1000
# dtype: int64

# %%
correlations = df[['Number_of_Riders','Number_of_Drivers','Number_of_Past_Rides','Average_Ratings','Expected_Ride_Duration','Historical_Cost_of_Ride']].corr()
historical_cost_corr = correlations['Historical_Cost_of_Ride']
print(historical_cost_corr)
# Out:
# Number_of_Riders           0.005826
# Number_of_Drivers          0.017082
# Number_of_Past_Rides       0.035859
# Average_Ratings           -0.001063
# Expected_Ride_Duration     0.927547
# Historical_Cost_of_Ride    1.000000
# Name: Historical_Cost_of_Ride, dtype: float64

# %%
corr_matrix = df[['Number_of_Riders','Number_of_Drivers','Number_of_Past_Rides','Average_Ratings','Expected_Ride_Duration','Historical_Cost_of_Ride']].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
sns.boxplot(df)
plt.title("boxplot of pricing data")
plt.xticks(rotation=80)
plt.show()

# %%
plt.scatter(df['Number_of_Riders'],df['Number_of_Drivers'])
plt.xlabel('Riders')
plt.ylabel('  Drivers')
plt.show()

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(14, 8))
plt.subplot(1, 3, 1)
plt.scatter(df['Number_of_Riders'], df['Historical_Cost_of_Ride'], alpha=0.5)
plt.xlabel('Number of Riders')
plt.ylabel('Historical Cost of Ride')
plt.title('Number of Riders vs Historical Cost of Ride')


plt.subplot(1, 3, 2)
plt.scatter(df['Number_of_Drivers'], df['Historical_Cost_of_Ride'], alpha=0.5)
plt.xlabel('Number of Drivers')
plt.ylabel('Historical Cost of Ride')
plt.title('Number of Drivers vs Historical Cost of Ride')

plt.subplot(1, 3, 3)
plt.scatter(df['Expected_Ride_Duration'], df['Historical_Cost_of_Ride'], alpha=0.5)
plt.xlabel('Expected Ride Duration')
plt.ylabel('Historical Cost of Ride')
plt.title('Expected Ride Duration vs Historical Cost of Ride')



plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Define the target variable
target_variable = 'Historical_Cost_of_Ride'

# Get the list of features
features = [col for col in df.columns if col != target_variable]

# Create a figure with subplots
plt.figure(figsize=(16, 12))

# Plot each feature against the target variable
for i, feature in enumerate(features):
    plt.subplot(4, 3, i + 1)  # Adjust subplot grid size as needed
    plt.scatter(df[feature], df[target_variable], alpha=0.5)
    plt.xlabel(feature)
    plt.ylabel(target_variable)
    plt.title(f'{feature} vs {target_variable}')

# Adjust layout to prevent overlapping
plt.tight_layout()
plt.show()

# %%
vehicle_types = df['Vehicle_Type'].unique()
colors = plt.cm.tab10(range(len(vehicle_types)))
color_mapping = dict(zip(vehicle_types, colors))

bar_colors = df['Vehicle_Type'].map(color_mapping)

plt.figure(figsize=(10, 8))
plt.barh(df['Time_of_Booking'], df['Number_of_Drivers'], color=bar_colors)

plt.xlabel('Time of Booking')
plt.ylabel('Number of Drivers')
plt.title('Time of Booking vs Number of Drivers by Vehicle Type')

handles = [plt.Rectangle((0,0),1,1, color=color_mapping[vt]) for vt in vehicle_types]
plt.legend(handles, vehicle_types, loc='upper right')
plt.show()

# %%
from sklearn.linear_model import LinearRegression
x=df[['Number_of_Riders','Number_of_Drivers','Number_of_Past_Rides','Average_Ratings','Expected_Ride_Duration']]
y=df['Historical_Cost_of_Ride']

# %%
x
# Out:
#      Number_of_Riders  Number_of_Drivers  Number_of_Past_Rides  \
# 0                  90                 45                    13
# 1                  58                 39                    72
# 2                  42                 31                     0
# 3                  89                 28                    67
# 4                  78                 22                    74
# ..                ...                ...                   ...
# 995                33                 23                    24
# 996                84                 29                    92
# 997                44                  6                    80
# 998                53                 27                    78
# 999                78                 63                    14
#
#      Average_Ratings  Expected_Ride_Duration
# 0               4.47                      90
# 1               4.06                      43
# 2               3.99                      76
# ...

# %%
y
# Out:
# 0      284.257273
# 1      173.874753
# 2      329.795469
# 3      470.201232
# 4      579.681422
#           ...
# 995     91.389526
# 996    424.155987
# 997    157.364830
# 998    279.095048
# 999    655.065106
# Name: Historical_Cost_of_Ride, Length: 1000, dtype: float64

# %%
reg=LinearRegression()
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=3)

# %%
x_train
# Out:
#      Number_of_Riders  Number_of_Drivers  Number_of_Past_Rides  \
# 78                 72                 45                    82
# 109                40                 15                    90
# 201                54                 35                    66
# 465                42                 12                    92
# 143                61                 44                    69
# ..                ...                ...                   ...
# 952                26                  5                     7
# 643                94                 71                    48
# 249                28                 15                    90
# 664                95                 76                    74
# 874                20                 10                    18
#
#      Average_Ratings  Expected_Ride_Duration
# 78              4.42                      40
# 109             3.62                      42
# 201             4.40                      77
# ...

# %%
y_train
# Out:
# 78     151.580404
# 109    211.527729
# 201    234.071454
# 465    319.296713
# 143    132.214765
#           ...
# 952    413.548002
# 643    770.873324
# 249    511.929391
# 664    464.991583
# 874    450.387881
# Name: Historical_Cost_of_Ride, Length: 800, dtype: float64

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=reg.predict(x_test)

# %%
pd.DataFrame(y_pred)
# Out:
#               0
# 0    382.629570
# 1    555.982922
# 2    111.011097
# 3    507.410174
# 4     89.740655
# ..          ...
# 195  179.568618
# 196   60.147624
# 197  326.313824
# 198  579.653691
# 199  149.588618
#
# [200 rows x 1 columns]

# %%
y_test
# Out:
# 642    398.159384
# 762    532.509778
# 909    145.042238
# 199    521.801921
# 586     60.981817
#           ...
# 164    202.945457
# 782     91.677489
# 575    336.568484
# 992    632.560142
# 713    131.443587
# Name: Historical_Cost_of_Ride, Length: 200, dtype: float64

# %%
reg.score(x_test,y_test)
# Out:
# 0.8706773506193682
